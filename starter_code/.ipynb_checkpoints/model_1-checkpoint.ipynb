# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\besat\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\besat\anaconda3\lib\site-packages (from sklearn) (0.23.2)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\besat\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\besat\appdata\roaming\python\python38\site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\besat\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.5.4)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\besat\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.16.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\besat\anaconda3\lib\site-packages (0.16.0)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
import joblib

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
data = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
data = data.dropna(axis='columns', how='all')
# Drop the null rows
data = data.dropna()
data.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
for column, content in data.items():
    if data[column].dtype == 'int64':
        data = data.astype({column: 'float64'})

# %%
data.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED            0.0            0.0            0.0            0.0
# 1  FALSE POSITIVE            0.0            1.0            0.0            0.0
# 2  FALSE POSITIVE            0.0            1.0            0.0            0.0
# 3       CONFIRMED            0.0            0.0            0.0            0.0
# 4       CONFIRMED            0.0            0.0            0.0            0.0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...           -81.0      4.467           0.064
# 1          0.000581  ...          -176.0      4.544           0.044
# 2          0.000115  ...          -174.0      4.564           0.053
# 3          0.001130  ...          -211.0      4.438           0.070
# 4          0.001900  ...          -232.0      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Assign data to X and y
X = data.drop("koi_disposition", axis=1)
y = data["koi_disposition"]

# Split data into training and testing groups
#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
data.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED            0.0            0.0            0.0            0.0
# 1  FALSE POSITIVE            0.0            1.0            0.0            0.0
# 2  FALSE POSITIVE            0.0            1.0            0.0            0.0
# 3       CONFIRMED            0.0            0.0            0.0            0.0
# 4       CONFIRMED            0.0            0.0            0.0            0.0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...           -81.0      4.467           0.064
# 1          0.000581  ...          -176.0      4.544           0.044
# 2          0.000115  ...          -174.0      4.564           0.053
# 3          0.001130  ...          -211.0      4.438           0.070
# 4          0.001900  ...          -232.0      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6080            1.0            0.0            0.0            0.0   12.496435
# 3001            0.0            0.0            0.0            0.0   11.615625
# 570             0.0            1.0            0.0            0.0   10.980246
# 4897            1.0            0.0            0.0            0.0  466.908240
# 625             0.0            1.0            1.0            1.0    1.061933
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6080     2.213000e-04    -2.213000e-04   132.035800          0.014300
# 3001     1.528000e-04    -1.528000e-04   131.968430          0.008230
# 570      6.930000e-07    -6.930000e-07   137.137607          0.000053
# 4897     1.194000e-02    -1.194000e-02   136.373100          0.019000
# 625      1.250000e-06    -1.250000e-06   133.850441          0.000978
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6080         -0.014300  ...          -286.0      3.805           0.390
# 3001         -0.008230  ...           -72.0      4.083           0.368
# 570          -0.000053  ...          -159.0      4.462           0.098
# 4897         -0.019000  ...          -146.0      4.456           0.102
# 625          -0.000978  ...          -167.0      3.975           0.259
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6080          -0.130     2.730          0.535         -1.248  289.23080
# 3001          -0.092     1.453          0.218         -0.510  293.52756
# 570           -0.182     0.897          0.238         -0.119  282.79764
# 4897          -0.361     0.867          0.448         -0.103  297.65436
# 625           -0.111     1.851          0.383         -0.575  288.90253
#
#             dec  koi_kepmag
# 6080  44.412483      13.054
# 3001  41.111439      15.162
# 570   43.578129      14.212
# 4897  43.178551      15.202
# 625   44.632992      12.953
#
# [5 rows x 40 columns]

# %% [markdown]
# # Train the Model

# %%
model_1 = RandomForestClassifier(n_estimators=200)
model_1.fit(X_train_scaled, y_train)

model_1_training_score = round(model_1.score(X_train_scaled, y_train)*100,3)
base_accuracy = round(model_1.score(X_test_scaled, y_test)*100,3)

print(f"Training Data Score: {model_1_training_score} %")
print(f"Testing Data Score: {base_accuracy} %")
# Out:
# Training Data Score: 100.0 %
# Testing Data Score: 90.217 %

# %%
# Determine which features ought to be kept
feature_names = X.columns.tolist()
preSelected_features = sorted(zip(model_1.feature_importances_, feature_names), reverse=True)
ranked_features = pd.DataFrame(preSelected_features, columns=['Score', 'Feature'])
ranked_features = ranked_features.set_index('Feature')
ranked_features
# Out:
#                       Score
# Feature
# koi_fpflag_co      0.112125
# koi_fpflag_nt      0.090966
# koi_fpflag_ss      0.063490
# koi_model_snr      0.055617
# koi_prad           0.050087
# koi_duration_err2  0.035920
# koi_prad_err1      0.035895
# koi_fpflag_ec      0.035231
# koi_steff_err1     0.033352
# koi_duration_err1  0.032052
# koi_prad_err2      0.028020
# koi_steff_err2     0.027259
# koi_duration       0.024778
# koi_period         0.023095
# koi_depth          0.022425
# koi_time0bk_err1   0.022398
# koi_time0bk_err2   0.020417
# koi_impact         0.017762
# koi_period_err1    0.017500
# koi_insol_err1     0.017231
# koi_period_err2    0.017202
# koi_depth_err2     0.016453
# koi_teq            0.015515
# koi_insol          0.014580
# koi_depth_err1     0.014485
# ra                 0.013680
# koi_time0bk        0.013597
# koi_insol_err2     0.011835
# koi_srad_err1      0.011752
# koi_kepmag         0.011237
# koi_impact_err1    0.010935
# koi_slogg_err2     0.010697
# dec                0.010545
# koi_impact_err2    0.010468
# koi_steff          0.010010
# koi_slogg          0.009883
# koi_srad           0.009843
# koi_slogg_err1     0.009300
# koi_srad_err2      0.009016
# koi_tce_plnt_num   0.003349

# %% [markdown]
#  #  <font color=black>Feature Selection</font>

# %%
# Remove features with Score < 0.011
selected_features = []
for tup in preSelected_features:
    if tup[0] > 0.01:
        selected_features.append(tup[1])

# %% [markdown]
# ###  <font color=black>https://towardsdatascience.com/why-how-and-when-to-apply-feature-selection-e9c69adfabf2</font>

# %%
# Use new data for all subsequent models
## Assign new data to X 
X_train_select = X_train[selected_features]
X_test_select = X_test[selected_features]

X_scaler = MinMaxScaler().fit(X_train_select)
X_train_scaled = X_scaler.transform(X_train_select)
X_test_scaled = X_scaler.transform(X_test_select)

## Train new model
model_2 = RandomForestClassifier(n_estimators=200)
model_2.fit(X_train_scaled, y_train)

model_2_training_score = round(model_2.score(X_train_scaled, y_train)*100,3)
select_features_accuracy = round(model_2.score(X_test_scaled, y_test)*100,3)

print(f"Training Data Score: {model_2_training_score} %")
print(f"Testing Data Score: {select_features_accuracy} %")
# Out:
# Training Data Score: 100.0 %
# Testing Data Score: 89.874 %

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the RandomSearchCV model
model_3 = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [200, 600, 1200, 1400],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [14, 15, 16, 17, 18, None]
}
grid = GridSearchCV(model_3, param_grid, cv=5, verbose=3, n_jobs=-1)

# Train the model with GridSearch
_ = grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed: 18.8min finished

# %%
##print(grid.best_params_)
##print(grid.best_score_)

# %% [markdown]
# #  <font color=black>Train Tuned Model</font>

# %%
# Tuned parameters
max_features = grid.best_params_['max_features']
n_estimators = grid.best_params_['n_estimators']
max_depth = grid.best_params_['max_depth']
criterion = 'entropy'

# Tuned model
tuned_model = RandomForestClassifier(max_features=max_features, n_estimators=n_estimators, 
                                     criterion=criterion, max_depth=max_depth, random_state=42)
tuned_model.fit(X_train_scaled, y_train)

model_3_training_score = round(tuned_model.score(X_train_scaled, y_train)*100,3)
tuned_accuracy = round(tuned_model.score(X_test_scaled, y_test)*100,3)

print(f"Training Data Score: {model_3_training_score} %")
print(f"Testing Data Score: {tuned_accuracy} %")
# Out:
# Training Data Score: 97.788 %
# Testing Data Score: 90.446 %

# %% [markdown]
# ###  <font color=black>https://study.com/academy/lesson/entropy-in-machine-learning.html</font>

# %% [markdown]
# ### <font black>https://quantdare.com/decision-trees-gini-vs-entropy/</font>

# %% [markdown]
# #  <font color=black>Model Prediction and Evaluation/font>

# %%
# Predictions
predictions = tuned_model.predict(X_test_scaled)
classifications = y_test.unique().tolist()

prediction_actual = {
    'Actual': y_test,
    'Prediction': predictions
}

PA_df = pd.DataFrame(prediction_actual)
PA_df = PA_df.set_index('Actual').reset_index()
PA_df.head(15)
# Out:
#             Actual      Prediction
# 0        CANDIDATE       CANDIDATE
# 1   FALSE POSITIVE  FALSE POSITIVE
# 2   FALSE POSITIVE  FALSE POSITIVE
# 3   FALSE POSITIVE  FALSE POSITIVE
# 4        CANDIDATE       CANDIDATE
# 5   FALSE POSITIVE  FALSE POSITIVE
# 6        CANDIDATE       CANDIDATE
# 7   FALSE POSITIVE  FALSE POSITIVE
# 8   FALSE POSITIVE  FALSE POSITIVE
# 9   FALSE POSITIVE  FALSE POSITIVE
# 10  FALSE POSITIVE  FALSE POSITIVE
# 11  FALSE POSITIVE  FALSE POSITIVE
# 12       CONFIRMED       CONFIRMED
# 13  FALSE POSITIVE  FALSE POSITIVE
# 14  FALSE POSITIVE  FALSE POSITIVE

# %%
# Evaluations
evaluations = {'': ['Base Model', 'Select Features Model', 'Tuned Model'],
               'Accuracy': [f"{base_accuracy}%", f"{select_features_accuracy}%", f"{tuned_accuracy}%"]}

evaluations_df = pd.DataFrame(evaluations)
evaluations_df = evaluations_df.set_index('')

evaluations_df.to_csv('RandomForestClassifier_eval.csv')
evaluations_df
# Out:
#                       Accuracy
#
# Base Model             90.217%
# Select Features Model  89.874%
# Tuned Model            90.446%

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'BestModel_RandomForest.sav'
joblib.dump(tuned_model, filename)
# Out:
# ['BestModel_RandomForest.sav']
